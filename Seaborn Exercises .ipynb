# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns # import seaborn viz package
import matplotlib.pyplot as plt # import basic plot pack # the following line is so that plots auto generate
# %matplotlib inline

# %%
sns.set_style('whitegrid') #sets background style

# %%
titanic = sns.load_dataset('titanic') # import titanic data set

# %%
titanic.head() # view forst 5 lines of data
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# distribution joint plot
sns.jointplot(x = 'fare',y = 'age',data = titanic) # joint plot with x and y axis using data from titanic set
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#DO NOT WRITE HERE

# %%
# histogram 
# I am not sure what thisis suppose to be plotting, fare and then something, use plot lib
sns.distplot(titanic['fare'], bins = 30, kde = False, color = 'red')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#DO NOT WRITE HERE

# %%
#Box plots of class vs age 
sns.boxplot(x = 'class', y = 'age', data = titanic, palette = 'rainbow') # so I actaully like mine more
# the next step is chainging color and scale to match 
# also looks like we have to adjust the axis

# %%
#DO NOT WRITE HERE

# %%
# ugly tree plot or something 
#apparently these are called swarm plots 
sns.swarmplot(x = 'class', y = 'age', data = titanic, palette = 'Set2')

# %%
#DO NOT WRITE HERE

# %%
# Count plot 
sns.countplot(x = 'sex', data = titanic)

# %%
#DO NOT WRITE HERE

# %%
# Correlation plot
titanic.corr() # makes an automatic correlation matrix
sns.heatmap(titanic.corr(), cmap = 'coolwarm',annot = False)
#are some differences
# will have to take a look at the solution notes
plt.title('titanic.corr()'')
# Out:
#   File "<ipython-input-36-66a51300125c>", line 6
#     plt.title('titanic.corr()'')
#                                 ^
# SyntaxError: EOL while scanning string literal

# %%
#DO NOT WRITE HERE

# %%
# FacetGrid is general way to create grids of plots based off of a feature
g = sns.FaceGrid(titanic, col = )

# %%
#DO NOT WRITE HERE

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
